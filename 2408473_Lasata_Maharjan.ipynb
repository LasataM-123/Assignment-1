# %% [markdown]
# ##3.1 Problem - 1: Getting Started with Data Exploration - Some Warm up
# #Exercises:
# **1. Data Exploration and Understanding:**

# %% [markdown]
# **• Dataset Overview:**

# %% [markdown]
# 1. Load the dataset and display the first 10 rows.
# 2. Identify the number of rows and columns in the dataset.
# 3. List all the columns and their data types.

# %%
#importing the pandas library
import pandas as pd

# %%
#mounting the drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Q.no.1
#Loading the dataset to dataframes
df=pd.read_csv('/content/drive/MyDrive/Dataset/WHR-2024-5CS037.csv')
print(df)
# Out:
#          Country name  score  Log GDP per capita  Social support  \
# 0             Finland  7.741               1.844           1.572
# 1             Denmark  7.583               1.908           1.520
# 2             Iceland  7.525               1.881           1.617
# 3              Sweden  7.344               1.878           1.501
# 4              Israel  7.341               1.803           1.513
# ..                ...    ...                 ...             ...
# 138  Congo (Kinshasa)  3.295               0.534           0.665
# 139      Sierra Leone  3.245               0.654           0.566
# 140           Lesotho  3.186               0.771           0.851
# 141           Lebanon  2.707               1.377           0.577
# 142       Afghanistan  1.721               0.628           0.000
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                      0.695                         0.859       0.142
# ...

# %%
#Displaying the first 10 rows
print("First 10 rows = \n")
df.head(10)
# Out:
# First 10 rows =
#   Country name  score  Log GDP per capita  Social support  \
# 0      Finland  7.741               1.844           1.572
# 1      Denmark  7.583               1.908           1.520
# 2      Iceland  7.525               1.881           1.617
# 3       Sweden  7.344               1.878           1.501
# 4       Israel  7.341               1.803           1.513
# 5  Netherlands  7.319               1.901           1.462
# 6       Norway  7.302               1.952           1.517
# 7   Luxembourg  7.122               2.141           1.355
# 8  Switzerland  7.060               1.970           1.425
# 9    Australia  7.057               1.854           1.461
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.695                         0.859       0.142
# 1                    0.699                         0.823       0.204
# 2                    0.718                         0.819       0.258
# ...

# %%
#Q.no.2
#Ientifying the number of rows
no_of_rows=df.shape[0]

#Ientifying the number of columns
no_of_columns=df.shape[1]

print("Number of rows = ",no_of_rows)
print("Number of columns = ",no_of_columns)
# Out:
# Number of rows =  143
# Number of columns =  9

# %%
#Q.no.3
#Listing all the columns present in the dataset
all_columns=df.columns
print("All columns = \n",all_columns)
# Out:
# All columns =
#  Index(['Country name', 'score', 'Log GDP per capita', 'Social support',
#        'Healthy life expectancy', 'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Dystopia + residual'],
#       dtype='object')

# %%
#Listing the datatype of all columns
datatype=df.dtypes
print("Data types = \n",datatype)
# Out:
# Data types =
#  Country name                     object
# score                           float64
# Log GDP per capita              float64
# Social support                  float64
# Healthy life expectancy         float64
# Freedom to make life choices    float64
# Generosity                      float64
# Perceptions of corruption       float64
# Dystopia + residual             float64
# dtype: object

# %%
#storing the score column for code reusability
score_column=df['score']

# %% [markdown]
# **• Basic Statistics:**

# %% [markdown]
# 1. Calculate the mean, median, and standard deviation for the Score column.
# 2. Identify the country with the highest and lowest happiness scores.

# %%
#Q.no.1
#Calculating mean of the score column
score_mean=score_column.mean()
print("Mean of the score column = ",score_mean)
# Out:
# Mean of the score column =  5.52758041958042

# %%
#Calculating median of the score column
score_median=score_column.median()
print("Median of the score column = ",score_median)
# Out:
# Median of the score column =  5.785

# %%
#Calculating standard deviation of the score column
score_standard_deviation=score_column.std()
print("Standard deviation of the score column = ",score_standard_deviation)
# Out:
# Standard deviation of the score column =  1.1707165099442995

# %%
#Q.no.2
#Calculating the highest score present in the score column
highest_score=score_column.max()
print("Highest score = ",highest_score)
# Out:
# Highest score =  7.741

# %%
#Checking which country has that highest score and displaying it
highest_score_country=df[score_column==highest_score]
print("Country with highest score = ",highest_score_country['Country name'].values[0])
# Out:
# Country with highest score =  Finland

# %%
#Calculating the lowest score present in the score column
lowest_score=score_column.min()
print("Lowest score = ",lowest_score)
# Out:
# Lowest score =  1.721

# %%
#Checking which country has the lowest score and displaying it
lowest_score_country=df[score_column==lowest_score]
print("Country with lowest score = ",lowest_score_country['Country name'].values[0])
# Out:
# Country with lowest score =  Afghanistan

# %% [markdown]
# **• Missing Values:**

# %% [markdown]
# 1. Check if there are any missing values in the dataset. If so, display the total count for each column.

# %%
#Q.no.1
#Checking if there are missing values in the dataset and displaying it
df_missing_values=df.isnull()
print(df_missing_values)
# Out:
#      Country name  score  Log GDP per capita  Social support  \
# 0           False  False               False           False
# 1           False  False               False           False
# 2           False  False               False           False
# 3           False  False               False           False
# 4           False  False               False           False
# ..            ...    ...                 ...             ...
# 138         False  False               False           False
# 139         False  False               False           False
# 140         False  False               False           False
# 141         False  False               False           False
# 142         False  False               False           False
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                      False                         False       False
# 1                      False                         False       False
# ...

# %%
#Displaying the total count of missing values for each column
no_of_missing_values=df.isnull().sum()
print("Total count of missing values = \n",no_of_missing_values)
# Out:
# Total count of missing values =
#  Country name                    0
# score                           0
# Log GDP per capita              3
# Social support                  3
# Healthy life expectancy         3
# Freedom to make life choices    3
# Generosity                      3
# Perceptions of corruption       3
# Dystopia + residual             3
# dtype: int64

# %% [markdown]
# **• Filtering and Sorting:**

# %% [markdown]
# 1. Filter the dataset to show only the countries with a Score greater than 7.5.
# 2. For the filtered dataset - Sort the dataset by GDP per Capita in descending order and display the
# top 10 rows.

# %%
#Q.no.1
#Showing only the countries with a score greater than 7.5
filtered_dataset=df[score_column>7.5]
print("Countries with a Score greater than 7.5 = \n",filtered_dataset)
# Out:
# Countries with a Score greater than 7.5 =
#    Country name  score  Log GDP per capita  Social support  \
# 0      Finland  7.741               1.844           1.572
# 1      Denmark  7.583               1.908           1.520
# 2      Iceland  7.525               1.881           1.617
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.695                         0.859       0.142
# 1                    0.699                         0.823       0.204
# 2                    0.718                         0.819       0.258
#
#    Perceptions of corruption  Dystopia + residual
# 0                      0.546                2.082
# 1                      0.548                1.881
# 2                      0.182                2.050

# %%
#Q.no.2
#Sorting the dataset by GDP per Capita in descending order
sorted_dataset=df.sort_values(by='Log GDP per capita',ascending=False)
print("Sorted dataset by GDP per Capita in descending order = \n",sorted_dataset)
# Out:
# Sorted dataset by GDP per Capita in descending order =
#               Country name  score  Log GDP per capita  Social support  \
# 7              Luxembourg  7.122               2.141           1.355
# 16                Ireland  6.838               2.129           1.390
# 29              Singapore  6.523               2.118           1.361
# 21   United Arab Emirates  6.733               1.983           1.164
# 8             Switzerland  7.060               1.970           1.425
# ..                    ...    ...                 ...             ...
# 138      Congo (Kinshasa)  3.295               0.534           0.665
# 78              Venezuela  5.607               0.000           1.321
# 61                Bahrain  5.959                 NaN             NaN
# 87             Tajikistan  5.281                 NaN             NaN
# 102    State of Palestine  4.879                 NaN             NaN
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# ...

# %%
#Displaying the top 10 rows
sorted_10_rows=sorted_dataset.head(10)
print("Top 10 rows of the sorted dataset = \n",sorted_10_rows)
# Out:
# Top 10 rows of the sorted dataset =
#                   Country name  score  Log GDP per capita  Social support  \
# 7                  Luxembourg  7.122               2.141           1.355
# 16                    Ireland  6.838               2.129           1.390
# 29                  Singapore  6.523               2.118           1.361
# 21       United Arab Emirates  6.733               1.983           1.164
# 8                 Switzerland  7.060               1.970           1.425
# 6                      Norway  7.302               1.952           1.517
# 22              United States  6.725               1.939           1.392
# 85  Hong Kong S.A.R. of China  5.316               1.909           1.184
# 1                     Denmark  7.583               1.908           1.520
# 5                 Netherlands  7.319               1.901           1.462
#
#     Healthy life expectancy  Freedom to make life choices  Generosity  \
# ...

# %% [markdown]
# **• Adding New Columns:**

# %% [markdown]
# 1. Create a new column called Happiness Category that categorizes countries into three categories
# based on their Score:
#
# Low − (Score < 4)
# Medium − (4 ≤ Score ≤ 6)
# High − (Score > 6)

# %%
#Creating a new column
df['Happiness_Category']=pd.cut(score_column,bins=[0,4,6,10],labels=['Low','Medium','High'])
print("Including new column =\n",df.head)
# Out:
# Including new column =
#  <bound method NDFrame.head of          Country name  score  Log GDP per capita  Social support  \
# 0             Finland  7.741               1.844           1.572
# 1             Denmark  7.583               1.908           1.520
# 2             Iceland  7.525               1.881           1.617
# 3              Sweden  7.344               1.878           1.501
# 4              Israel  7.341               1.803           1.513
# ..                ...    ...                 ...             ...
# 138  Congo (Kinshasa)  3.295               0.534           0.665
# 139      Sierra Leone  3.245               0.654           0.566
# 140           Lesotho  3.186               0.771           0.851
# 141           Lebanon  2.707               1.377           0.577
# 142       Afghanistan  1.721               0.628           0.000
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# ...

# %% [markdown]
# **2. Data Visualizations:**

# %%
#import Matplotlib library
import matplotlib.pyplot as plt

# %% [markdown]
# • Bar Plot: Plot the top 10 happiest countries by Score using a bar chart.

# %%
#sorting the values by score in descending order and taking top 10 rows
top_10_countries=df.sort_values(by="score",ascending=False).head(10);

#Bar plot for top 10 happiest countries by score
plt.figure(figsize=(15,6))
plt.bar(top_10_countries['Country name'], top_10_countries['score'],edgecolor="grey", color='lightblue')
plt.xlabel('Country')
plt.ylabel('Score')
plt.title("Top 10 happiest countries by Score")
plt.show()

# %% [markdown]
# **• Line Plot: Plot the top 10 unhappiest countries by Score using a Line chart.**

# %%
#sorting the values by score in ascending order and taking top 10 rows
top_10_unhappiest_countries=df.sort_values(by="score",ascending=True).head(10)

#Bar plot for top 10 unhappiest countries by score
plt.figure(figsize=(15,6))
plt.plot(top_10_unhappiest_countries['Country name'], top_10_unhappiest_countries['score'], marker='*', linestyle='-', color='orange')
plt.xlabel('Country')
plt.ylabel('Score')
plt.title("Top 10 unhappiest countries by Score")
plt.show()

# %% [markdown]
# **• Plot a histogram for the Score column to show its distribution and also interpret.**

# %%
#Plotting a histogram for the Score column to show its distribution
plt.figure(figsize=(13,6))
plt.hist(score_column, bins=20, edgecolor='grey',color="lightblue")
plt.title("Score Distribution")
plt.xlabel("Score")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# Interpretation of the histogram:
#
#
# *  Shape: The above histogram is left skewed as the tail of the histogram is extended to the left and data is concentrated to the right side. It is unimodal as it has only one peak. And also, the above histogram has a wide spread which denotes that it has broad variation in happiness scores.
#
# *   Central Tendency: The above histogram is skewed not symmetrical so the mean is pulled towards the tail of the distribution which is the left side. The mode is the most repeated value which is the tallest bar or the peak of the histogram. Here, in the above histogram, median lies between the mean and the mode.
#
# *   Outliers: We can observe that one bar remains alone at the left side of the above histogram. That one bar indicates that there is one lower outlier in the data.

# %% [markdown]
# **• Scatter Plot: Plot a scatter plot between GDP per Capita and Score to visualize their relationship.**

# %%
#Plotting a scatter plot between GDP per Capita and Score to visualize their relationship.
plt.figure(figsize=(13,6))
plt.scatter(df['Log GDP per capita'],score_column,edgecolor="grey",color="skyblue")
plt.title("Scatter plot between GDP per Capita and Score")
plt.xlabel("GDP per Capita")
plt.ylabel("Score")
plt.show()

# %% [markdown]
# ##3.2 Problem - 2 - Some Advance Data Exploration Task:

# %% [markdown]
# **Task - 1 - Setup Task - Preparing the South-Asia Dataset:**

# %% [markdown]
# **Steps:**

# %% [markdown]
# 1. Define the countries in South Asia with a list for example:
# south asian countries = ["Afghanistan", "Bangladesh", "Bhutan", "India",
#
# "Maldives", "Nepal", "Pakistan", "Srilanka"]
#
# 2. Use the list from step - 1 to filtered the dataset {i.e. filtered out matching dataset from list.}
# 3. Save the filtered dataframe as separate CSV files for future use.

# %%
#Q.no.1
#Defining the countries in South Asia
south_asian_countries = ["Afghanistan", "Bangladesh", "Bhutan", "India", "Maldives", "Nepal", "Pakistan", "Sri Lanka"]

# %%
#Q.no.2
##Filtering to extract rows corresponding to the countries in south_asian_countries
SouthAsia=df[df['Country name'].isin(south_asian_countries)]
print("Filtered countries = \n")
SouthAsia.head(6)
# Out:
# Filtered countries =
#     Country name  score  Log GDP per capita  Social support  \
# 92         Nepal  5.158               0.965           0.990
# 107     Pakistan  4.657               1.069           0.600
# 125        India  4.054               1.166           0.653
# 127    Sri Lanka  3.898               1.361           1.179
# 128   Bangladesh  3.886               1.122           0.249
# 142  Afghanistan  1.721               0.628           0.000
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 92                     0.443                         0.653       0.209
# 107                    0.321                         0.542       0.144
# 125                    0.417                         0.767       0.174
# 127                    0.586                         0.583       0.144
# 128                    0.513                         0.775       0.140
# 142                    0.242                         0.000       0.091
#
# ...

# %%
#Q.no.3
#Saving the filtered dataframe as a separate csv
SouthAsia.to_csv('/content/drive/MyDrive/Dataset/filtered_countries.csv',index=False)

# %% [markdown]
# **Task - 2 - Composite Score Ranking:**
#
# **Tasks:**

# %% [markdown]
# 1. Using the SouthAsia DataFrame, create a new column called Composite Score that combines the
# following metrics:
#
# Composite Score = 0.40 × GDP per Capita + 0.30 × Social Support
#
# + 0.30 × Healthy Life Expectancy
# 2. Rank the South Asian countries based on the Composite Score in descending order.
# 3. Visualize the top 5 countries using a horizontal bar chart showing the Composite Score.
# 4. Discuss whether the rankings based on the Composite Score align with the original Score - support your
# discussion with some visualization plot.

# %%
#Q.no.1
#Creating a new column
SouthAsia.loc[:,'Composite Score']=0.40*SouthAsia['Log GDP per capita']+0.30*SouthAsia['Social support']+0.30*SouthAsia['Healthy life expectancy']
SouthAsia.head(6)
# Out:
#     Country name  score  Log GDP per capita  Social support  \
# 92         Nepal  5.158               0.965           0.990
# 107     Pakistan  4.657               1.069           0.600
# 125        India  4.054               1.166           0.653
# 127    Sri Lanka  3.898               1.361           1.179
# 128   Bangladesh  3.886               1.122           0.249
# 142  Afghanistan  1.721               0.628           0.000
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 92                     0.443                         0.653       0.209
# 107                    0.321                         0.542       0.144
# 125                    0.417                         0.767       0.174
# 127                    0.586                         0.583       0.144
# 128                    0.513                         0.775       0.140
# 142                    0.242                         0.000       0.091
#
# ...

# %%
#Q.no.2
#Ranking the South Asian countries based on the Composite Score in descending order.
ranking_countries=SouthAsia.sort_values(by='Composite Score',ascending=False)
ranking_countries.head(6)
# Out:
#     Country name  score  Log GDP per capita  Social support  \
# 127    Sri Lanka  3.898               1.361           1.179
# 92         Nepal  5.158               0.965           0.990
# 125        India  4.054               1.166           0.653
# 107     Pakistan  4.657               1.069           0.600
# 128   Bangladesh  3.886               1.122           0.249
# 142  Afghanistan  1.721               0.628           0.000
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 127                    0.586                         0.583       0.144
# 92                     0.443                         0.653       0.209
# 125                    0.417                         0.767       0.174
# 107                    0.321                         0.542       0.144
# 128                    0.513                         0.775       0.140
# 142                    0.242                         0.000       0.091
#
# ...

# %%
#Q.no.3
#Visualizing the top 5 countries using a horizontal bar chart showing the Composite Score.
plt.figure(figsize=(13,6))
plt.barh(ranking_countries['Country name'].head(),ranking_countries['Composite Score'].head(),edgecolor="grey",color="lightblue")
plt.title("Composite Score of top 5 countries")
plt.xlabel("Composite Score")
plt.ylabel("Countries")
plt.show()

# %%
#Q.no.4
#Adding new columns for rankings based on original score and composite score
SouthAsia.loc[:,'original_rank']=SouthAsia['score'].rank(ascending=False)
SouthAsia.loc[:,'composite_rank']=SouthAsia['Composite Score'].rank(ascending=False)
SouthAsia.head()
# Out:
#     Country name  score  Log GDP per capita  Social support  \
# 92         Nepal  5.158               0.965           0.990
# 107     Pakistan  4.657               1.069           0.600
# 125        India  4.054               1.166           0.653
# 127    Sri Lanka  3.898               1.361           1.179
# 128   Bangladesh  3.886               1.122           0.249
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 92                     0.443                         0.653       0.209
# 107                    0.321                         0.542       0.144
# 125                    0.417                         0.767       0.174
# 127                    0.586                         0.583       0.144
# 128                    0.513                         0.775       0.140
#
#      Perceptions of corruption  Dystopia + residual Happiness_Category  \
# 92                       0.115                1.783             Medium
# ...

# %%
#Plotting a scatter plot to discuss whether the rankings based on the Composite Score align with the original Score
plt.figure(figsize=(13,6))
plt.scatter(SouthAsia['original_rank'],SouthAsia['composite_rank'],edgecolor="grey",color="orange")
plt.title("Rankings of South Asian countries")
plt.xlabel("Original Ranks")
plt.ylabel("Composite Ranks")
plt.show()

# %% [markdown]
# The above scatter plot is used as a visualization plot to discuss whether the rankings based on the Composite Score align with the original score. To attain this, we first add two new columns: original_rank and composite_rank in the SouthAsia dataframe that determine the rankings of the countries based on original score and the composite score.
#
# We have plotted Original rankings on the X-axis whereas Composite rankings on the Y-axis. From the above scatter plot, we can observe that the rankings almost align but there is a slight difference between Pakistan and India. As well as the composite rank of Sri Lanka is 1 whereas its  original rank is 4.

# %% [markdown]
# **Task - 3 - Outlier Detection:**
#
# **Tasks:**

# %% [markdown]
# 1. Identify outlier countries in South Asia based on their Score and GDP per Capita.
# 2. Define outliers using the 1.5 × IQR rule.
# 3. Create a scatter plot with GDP per Capita on the x-axis and Score on the y-axis, highlighting outliers
# in a different color.
# 4. Discuss the characteristics of these outliers and their potential impact on regional averages.

# %%
#For score column,
#Finding quartile 1 (Q1)
Q1_score=SouthAsia['score'].quantile(0.25)

#Finding quartile 3 (Q3)
Q3_score=SouthAsia['score'].quantile(0.75)

#Finding interquartile range
IQR_score=Q3_score-Q1_score

#Finding the lower and upper outliers
outlier_score_lower=Q1_score-1.5*IQR_score
outlier_score_upper=Q3_score+1.5*IQR_score

#Finding the rows that meet the outliers' condition
score_outliers=SouthAsia[(SouthAsia['score']<outlier_score_lower) | (SouthAsia['score']>outlier_score_upper)]
print("Outliers in score column = \n")
score_outliers.head()
# Out:
# Outliers in score column =
#     Country name  score  Log GDP per capita  Social support  \
# 142  Afghanistan  1.721               0.628             0.0
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 142                    0.242                           0.0       0.091
#
#      Perceptions of corruption  Dystopia + residual Happiness_Category  \
# 142                      0.088                0.672                Low
#
#      Composite Score  original_rank  composite_rank
# 142           0.3238            6.0             6.0

# %%
#For Log GDP per capita column,
#Finding quartile 1 (Q1)
Q1_gdp=SouthAsia['Log GDP per capita'].quantile(0.25)

#Finding quartile 3 (Q3)
Q3_gdp=SouthAsia['Log GDP per capita'].quantile(0.75)

#Finding interquartile range
IQR_gdp=Q3_gdp-Q1_gdp

#Finding the lower and upper outliers
outlier_gdp_lower=Q1_gdp-1.5*IQR_gdp
outlier_gdp_upper=Q3_gdp+1.5*IQR_gdp

#Finding the rows that meet the outliers' condition
gdp_outliers=SouthAsia[(SouthAsia['Log GDP per capita']<outlier_gdp_lower) | (SouthAsia['Log GDP per capita']>outlier_gdp_upper)]
print("Outliers in Log GDP per capita column = \n")
gdp_outliers.head()
# Out:
# Outliers in Log GDP per capita column =
#     Country name  score  Log GDP per capita  Social support  \
# 142  Afghanistan  1.721               0.628             0.0
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 142                    0.242                           0.0       0.091
#
#      Perceptions of corruption  Dystopia + residual Happiness_Category  \
# 142                      0.088                0.672                Low
#
#      Composite Score  original_rank  composite_rank
# 142           0.3238            6.0             6.0

# %%
#Storing the columns for reusability
gdp_column=SouthAsia['Log GDP per capita']
score_column=SouthAsia['score']

# %%
plt.figure(figsize=(10,6))
#Scatter plot for normal points(non outliers)
non_outliers= (
    (gdp_column >= outlier_gdp_lower) & (gdp_column <= outlier_gdp_upper) &
    (score_column >= outlier_score_lower) & (score_column <= outlier_score_upper)
)
plt.scatter(
    gdp_column[non_outliers],
    score_column[non_outliers],
    color='black', label='Non-outliers'
)

#Scatter plot for Lower outliers
lower_outliers= (
    (gdp_column < outlier_gdp_lower) | (score_column < outlier_score_lower)
)
plt.scatter(
    gdp_column[lower_outliers],
    score_column[lower_outliers],
    color='red', label='Lower Outliers'
)

#Scatter plot for Upper outliers
upper_outliers = (
    (gdp_column > outlier_gdp_upper) | (score_column > outlier_score_upper)
)
plt.scatter(
    gdp_column[upper_outliers],
    score_column[upper_outliers],
    color='green', label='Upper Outliers'
)

# Adding legend, xlabel, ylabel and title
plt.legend()
plt.xlabel('Log GDP per capita')
plt.ylabel('Score')
plt.title('Scatter Plot of Non-Outliers and Outliers')
plt.show()

# %% [markdown]
# 4 - > Observing all the calculations and the scatter plot, Afghanistan seems to have the lowest score and Log GDP per capita which represents economic underdevelopment compared to other 4 South Asian countries as well as it has low values in some related indicators such as social support, life expectancy, etc.
#
# Due to the lower score and Log GDP per capita of Afghanistan, this may skew the regional averages downward which misinterprets the overall social progress and economic development of South Asia.

# %% [markdown]
# **Task - 4 - Exploring Trends Across Metrics:**
#
# **Tasks:**

# %% [markdown]
# 1. Choose two metrics (e.g., Freedom to Make Life Choices and Generosity) and calculate their correlation
# {pearson correlation} with the Score for South Asian countries.
# 2. Create scatter plots with trendlines for these metrics against the Score.
# 3. Identify and discuss the strongest and weakest relationships between these metrics and the Score for
# South Asian countries.

# %%
#Q.no.1
#Choosing two metrics and score column
metric_1=SouthAsia['Freedom to make life choices']
metric_2=SouthAsia['Generosity']
score=SouthAsia['score']

# %%
#Calculating the mean of score column
score_mean=score.mean()

# %%
#Declaring a function for better code reusability
def correlation_coefficient(X,Y):
  '''
  This function calculates the pearson correlation coeeficient between two columns.
  Parameters:
  X: First column passed by the user
  Y: Second column passed by the user
  Returns:
  correlation_coefficient: Pearson correlation coefficient between X and Y
  '''

  #Calculating the mean of X and Y
  X_mean=X.mean()
  Y_mean=Y.mean()

  #Calculating the numerator
  numerator=sum((X-X_mean)*(Y-Y_mean))

  #Calculating the denominator
  denominator=(sum((X-X_mean)**2)*sum((Y-Y_mean)**2))**0.5

  #Calculating the correlation coefficient
  correlation_coefficient=numerator/denominator

  #returning the correlation coefficient
  return correlation_coefficient

# %%
print("Pearson correlation coefficient of metric_1 with score = ",format(correlation_coefficient(metric_1,score),'.3f'))
print("Pearson correlation coefficient of metric_2 with score = ",format(correlation_coefficient(metric_2,score),'.3f'))
# Out:
# Pearson correlation coefficient of metric_1 with score =  0.801
# Pearson correlation coefficient of metric_2 with score =  0.875

# %%
#importing Seaborn library
import seaborn as sns

# %%
#Q.no.2
#Scatter plot with trendline for metric_1
plt.figure(figsize=(8,6))
sns.regplot(x=metric_1, y=score, data=df, ci=None, scatter_kws={'color': 'blue','s': 50}, line_kws={'color': 'red','label':'trendline'})
plt.xlabel("Freedom to make life choices")
plt.ylabel("Score")
plt.title("Scatter plot of Freedom to make life choices with score")
plt.legend()
plt.show()

# %%
#Scatter plot with trendline for metric_2
plt.figure(figsize=(8,6))
sns.regplot(x=metric_2, y=score, data=df, ci=None, scatter_kws={'color': 'orange','s': 50}, line_kws={'color': 'purple','label':'trendline'})
plt.xlabel("Generosity")
plt.ylabel("Score")
plt.title("Scatter plot of Generosity with score")
plt.legend()
plt.show()

# %% [markdown]
# 3 - > Observation:
# After calculating the pearson correlation coefficients of both freedom to make life choices and Generosity with score, we can observe that the values of both the coefficients are close to 1 ( For freedom to make life choices: 0.801 and for generosity: 0.875) which indicates a strong positive relationship of freedom to make life choices with score as well as generosity with score. This means that when the freedom to make life choices increases, score also increases as well as when generosity increases, score also increases.
#
# We can observe that the trendlines for both freedom to make life choices and generosity with score slopes upward which also indicates a positive relationship i.e. higher freedom to make life choices/higher generosity tends to be associated with higher score.

# %% [markdown]
# **Task - 5 - Gap Analysis:**
#
# **Tasks:**

# %% [markdown]
# 1. Add a new column, GDP-Score Gap, which is the difference between GDP per Capita and the Score
# for each South Asian country.
# 2. Rank the South Asian countries by this gap in both ascending and descending order.
# 3. Highlight the top 3 countries with the largest positive and negative gaps using a bar chart.
# 4. Analyze the reasons behind these gaps and their implications for South Asian countries.

# %%
#Q.no.1
#Adding a new column, GDP-Score Gap, which is the difference between GDP per Capita and the Score
SouthAsia.loc[:,'GDP-Score Gap']=SouthAsia['Log GDP per capita']-SouthAsia['score']
SouthAsia.head(6)
# Out:
#     Country name  score  Log GDP per capita  Social support  \
# 92         Nepal  5.158               0.965           0.990
# 107     Pakistan  4.657               1.069           0.600
# 125        India  4.054               1.166           0.653
# 127    Sri Lanka  3.898               1.361           1.179
# 128   Bangladesh  3.886               1.122           0.249
# 142  Afghanistan  1.721               0.628           0.000
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 92                     0.443                         0.653       0.209
# 107                    0.321                         0.542       0.144
# 125                    0.417                         0.767       0.174
# 127                    0.586                         0.583       0.144
# 128                    0.513                         0.775       0.140
# 142                    0.242                         0.000       0.091
#
# ...

# %%
#Q.no.2
#Ranking in ascending order
Ascending_rank=SouthAsia['GDP-Score Gap'].rank(ascending=True)
print("Ranking South Asian countries in ascenfding order =\n",Ascending_rank)
# Out:
# Ranking South Asian countries in ascenfding order =
#  92     1.0
# 107    2.0
# 125    3.0
# 127    5.0
# 128    4.0
# 142    6.0
# Name: GDP-Score Gap, dtype: float64

# %%
#Ranking in descending order
Descending_rank=SouthAsia['GDP-Score Gap'].rank(ascending=False)
print("Ranking South Asian countries in descending order =\n",Descending_rank)
# Out:
# Ranking South Asian countries in descending order =
#  92     6.0
# 107    5.0
# 125    4.0
# 127    2.0
# 128    3.0
# 142    1.0
# Name: GDP-Score Gap, dtype: float64

# %%
#Q.no.3
#Highlighting the top 3 countries with the largest positive and negative gaps using a bar chart.
ascending_sort=SouthAsia.sort_values(by="GDP-Score Gap",ascending=False)

#Plotting bar graph
plt.figure(figsize=(10,6))
plt.bar(ascending_sort['Country name'].head(3),ascending_sort['GDP-Score Gap'].head(3),color="skyblue",edgecolor="black",label="Positive")
plt.bar(ascending_sort['Country name'].tail(3),ascending_sort['GDP-Score Gap'].tail(3),color="orange",edgecolor="black",label="Negative")
plt.xlabel("Country")
plt.ylabel("GDP-Score Gap")
plt.title("Top 3 countries with largest positive and negative gaps")
plt.legend()
plt.show()

# %% [markdown]
# Here, We know GDP-Score Gap is the difference between the values in Log GDP per capita column and score column. The implication of the gap for South Asian countries is that the values of GDP-Score Gap is negative for all the countries which indicates that score is much higher than Log GDP per capita. So, the bar graph that we obtain for Top 3 countries with positive and negative gaps is extending downwards to represent negative values. It is observed that Nepal has the largest negative gap, and Afghanistan has the largest positive gap between GDP per capita and score.

# %% [markdown]
# ##3.3 Problem - 3 - Comparative Analysis:

# %% [markdown]
# **Task - 1 - Setup Task - Preparing the Middle Eastern Dataset:**
#
# **Tasks:**

# %% [markdown]
# 1. Similar in Task - 1 of Problem 2 create a dataframe from middle eastern countries. For hint use the
# following list:
# middle east countries = [ "Bahrain", "Iran", "Iraq", "Israel", "Jordan",
# "Kuwait", "Lebanon", "Oman", "Palestine", "Qatar", "Saudi Arabia", "Syria",
#
# "United Arab Emirates", "Yemen"]
#
# Complete the following task:

# %%
#Creating a dataframe from middle eastern countries
middle_eastern_countries = ["Bahrain", "Iran", "Iraq", "Israel", "Jordan", "Kuwait", "Lebanon", "Oman", "Palestine", "Qatar", "Saudi Arabia", "Syria", "United Arab Emirates", "Yemen"]

#Filtering to extract rows corresponding to the countries in middle_eatern_countries
MiddleEast=df[df['Country name'].isin(middle_eastern_countries)]
print("Middle east countries  = \n")
MiddleEast.head(10)
# Out:
# Middle east countries  =
#              Country name  score  Log GDP per capita  Social support  \
# 4                  Israel  7.341               1.803           1.513
# 12                 Kuwait  6.951               1.845           1.364
# 21   United Arab Emirates  6.733               1.983           1.164
# 27           Saudi Arabia  6.594               1.842           1.361
# 61                Bahrain  5.959                 NaN             NaN
# 91                   Iraq  5.166               1.249           0.996
# 99                   Iran  4.923               1.435           1.136
# 124                Jordan  4.186               1.262           0.983
# 132                 Yemen  3.561               0.671           1.281
# 141               Lebanon  2.707               1.377           0.577
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 4                      0.740                         0.641       0.153
# ...

# %%
MiddleEast.dropna(inplace=True)
MiddleEast.head(10)
# Out:
# <ipython-input-111-1b5137e989c1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   MiddleEast.dropna(inplace=True)
#              Country name  score  Log GDP per capita  Social support  \
# 4                  Israel  7.341               1.803           1.513
# 12                 Kuwait  6.951               1.845           1.364
# 21   United Arab Emirates  6.733               1.983           1.164
# 27           Saudi Arabia  6.594               1.842           1.361
# 91                   Iraq  5.166               1.249           0.996
# 99                   Iran  4.923               1.435           1.136
# 124                Jordan  4.186               1.262           0.983
# 132                 Yemen  3.561               0.671           1.281
# ...

# %% [markdown]
# **1. Descriptive Statistics:**
#
# • Calculate the mean, Standard deviation of the score for both South Asia and Middle East.
#
# • Which region has higher happiness Scores on average?

# %%
#Calculating mean of score for south asia and middle east
mean_score_south_asia=SouthAsia['score'].mean()
print("Mean score of South Asia = ",format(mean_score_south_asia,'.3f'))

mean_score_middle_east=MiddleEast['score'].mean()
print("Mean score of Middle East = ",format(mean_score_middle_east,'.3f'))
# Out:
# Mean score of South Asia =  3.896
# Mean score of Middle East =  5.351

# %%
#Calculating standard deviation of the score for south asia and middle east
std_score_south_asia=SouthAsia['score'].std()
print("Standard deviation of score of South Asia = ",format(std_score_south_asia,'.3f'))

std_score_middle_east=MiddleEast['score'].std()
print("Standard deviation of score of Middle East = ",format(std_score_middle_east,'.3f'))
# Out:
# Standard deviation of score of South Asia =  1.177
# Standard deviation of score of Middle East =  1.649

# %%
#Comparing mean score of South Asia and Middle East
if mean_score_south_asia > mean_score_middle_east:
    print("South Asia has higher happiness scores on average.")
else:
    print("Middle East has higher happiness scores on average.")
# Out:
# Middle East has higher happiness scores on average.

# %% [markdown]
# **2. Top and Bottom Performers:**
#
# • Identify the top 3 and bottom 3 countries in each region based on the score.
#
# • Plot bar charts comparing these charts.

# %%
#For SouthAsia, calculating top 3 and bottom 3 countries
top_3_south_asia=SouthAsia.sort_values(by="score",ascending=False).head(3)
print("Top 3 countries in South Asia = \n",top_3_south_asia)
# Out:
# Top 3 countries in South Asia =
#      Country name  score  Log GDP per capita  Social support  \
# 92         Nepal  5.158               0.965           0.990
# 107     Pakistan  4.657               1.069           0.600
# 125        India  4.054               1.166           0.653
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 92                     0.443                         0.653       0.209
# 107                    0.321                         0.542       0.144
# 125                    0.417                         0.767       0.174
#
#      Perceptions of corruption  Dystopia + residual Happiness_Category  \
# 92                       0.115                1.783             Medium
# 107                      0.074                1.907             Medium
# 125                      0.122                0.756             Medium
#
#      Composite Score  original_rank  composite_rank  GDP-Score Gap
# ...

# %%
bottom_3_south_asia=SouthAsia.sort_values(by="score",ascending=True).head(3)
print("Bottom 3 countries in South Asia = \n",bottom_3_south_asia)
# Out:
# Bottom 3 countries in South Asia =
#      Country name  score  Log GDP per capita  Social support  \
# 142  Afghanistan  1.721               0.628           0.000
# 128   Bangladesh  3.886               1.122           0.249
# 127    Sri Lanka  3.898               1.361           1.179
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 142                    0.242                         0.000       0.091
# 128                    0.513                         0.775       0.140
# 127                    0.586                         0.583       0.144
#
#      Perceptions of corruption  Dystopia + residual Happiness_Category  \
# 142                      0.088                0.672                Low
# 128                      0.167                0.919                Low
# 127                      0.031                0.014                Low
#
#      Composite Score  original_rank  composite_rank  GDP-Score Gap
# ...

# %%
#For Middle East, calculating top 3 and bottom 3 countries
top_3_middle_east=MiddleEast.sort_values(by="score",ascending=False).head(3)
print("Top 3 countries in Middle East = \n",top_3_middle_east)
# Out:
# Top 3 countries in Middle East =
#              Country name  score  Log GDP per capita  Social support  \
# 4                 Israel  7.341               1.803           1.513
# 12                Kuwait  6.951               1.845           1.364
# 21  United Arab Emirates  6.733               1.983           1.164
#
#     Healthy life expectancy  Freedom to make life choices  Generosity  \
# 4                     0.740                         0.641       0.153
# 12                    0.661                         0.827       0.200
# 21                    0.563                         0.815       0.209
#
#     Perceptions of corruption  Dystopia + residual Happiness_Category
# 4                       0.193                2.298               High
# 12                      0.172                1.884               High
# 21                      0.258                1.741               High

# %%
bottom_3_middle_east=MiddleEast.sort_values(by="score",ascending=True).head(3)
print("Bottom 3 countries in Middle East = \n",bottom_3_middle_east)
# Out:
# Bottom 3 countries in Middle East =
#      Country name  score  Log GDP per capita  Social support  \
# 141      Lebanon  2.707               1.377           0.577
# 132        Yemen  3.561               0.671           1.281
# 124       Jordan  4.186               1.262           0.983
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 141                    0.556                         0.173       0.068
# 132                    0.293                         0.362       0.080
# 124                    0.594                         0.593       0.059
#
#      Perceptions of corruption  Dystopia + residual Happiness_Category
# 141                      0.029               -0.073                Low
# 132                      0.113                0.760                Low
# 124                      0.189                0.504             Medium

# %%
#Plotting two bar charts for top 3 happiest countries in South Asia and Middle East
plt.figure(figsize=(10,6))
#bar chart for top 3 of Middle East
plt.bar(top_3_middle_east['Country name'],top_3_middle_east['score'],color="orange",edgecolor="black",label="Middle East")

#bar chart for top 3 of South Asia
plt.bar(top_3_south_asia['Country name'],top_3_south_asia['score'],color="lightblue",edgecolor="black",label="South Asia")

plt.xlabel("Countries")
plt.ylabel("Happiness Score")
plt.title("Top 3 happiest countries from South Asia and Middle East")
plt.legend(title="Top 3")
plt.show()

# %% [markdown]
# - > Comparing the bar charts for both South Asia and Middle East, we can observe that Israel is the happiest country in Middle East  with a happiness score of 7.341 and Nepal is the happiest country in South Asia with a happiness score of 5.158. Overall, we can observe that Israel is the happiest country with a happiness score more than that of the top 3 happiest countries in South Asia.

# %%
#Plotting two bar charts for top 3 unhappiest countries in South Asia and Middle East
plt.figure(figsize=(10,6))

#bar chart for bottom 3 of South Asia
plt.bar(bottom_3_south_asia['Country name'],bottom_3_south_asia['score'],color="pink",edgecolor="black",label="South Asia")

#bar chart for bottom 3 of Middle East
plt.bar(bottom_3_middle_east['Country name'],bottom_3_middle_east['score'],color="brown",edgecolor="black",label="Middle East")
plt.xlabel("Countries")
plt.ylabel("Happiness Score")
plt.title("Top 3 unhappiest countries from South Asia and Middle East")
plt.legend(title="Bottom 3")
plt.show()

# %% [markdown]
# - > Comparing the bar charts for both South Asia and Middle East, we can observe that Lebanon is the unhappiest country in Middle East  with a happiness score of 2.707 and Afghanistan is the unhappiest country in South Asia with a happiness score of 1.721. Overall, we can observe that Afghanistan is the unhappiest country with a happiness score less than that of the Top 3 unhappiest countries in Middle East.

# %% [markdown]
# **3. Metric Comparisons:**
#
# • Compare key metrics like GDP per Capita, Social Support, and Healthy Life Expectancy
# between the regions using grouped bar charts.
#
# • Which metrics show the largest disparity between the two regions?

# %%
#Creating a list of all key metrics to be compared
required_metrics = ['Country name', 'Log GDP per capita', 'Social support', 'Healthy life expectancy']

#Setting the country name as index for both the regions
middle_east= MiddleEast[required_metrics].set_index('Country name')
south_asian=SouthAsia[required_metrics].set_index('Country name')

#Finding mean of the other three columns each of both the regions
middle_east_avg = middle_east.mean()
south_asian_avg = south_asian.mean()

#Creating a new dataframe by combining the averages
comp_df= pd.DataFrame({
    'MiddleEast': middle_east_avg,
    'SouthAsia': south_asian_avg
})

#Plotting the bar chart for better visual separation between the data of two regions
comp_df.plot(kind='bar', figsize=(10,6),color=["skyblue","orange"],edgecolor='black')
plt.xticks(rotation=360)
plt.xlabel('Key metrics')
plt.ylabel('Average Values')
plt.title('Comparison of Key Metrics Between Middle East and South Asia')
plt.legend(title='Region')
plt.tight_layout()
plt.show()

# %% [markdown]
# - > The above grouped bar graph presents the comparison of key metrics between Middle East region and South Asia region. We can observe that there is a greater difference in values for metric Social Support between the two regions. Therefore, Social support shows the largest disparity between the two regions.

# %% [markdown]
# **4. Happiness Disparity:**
#
# • Compute the range (max - min) and coefficient of variation (CV) for Score in both regions.
#
# • Which region has greater variability in happiness?

# %%
#Finding maximum score
max_score_south_asia = SouthAsia['score'].max()

#Finding minimum score
min_score_south_asia =SouthAsia['score'].min()

#Computing range for score in South Asia
range_south_asia =max_score_south_asia-min_score_south_asia
print("The range for score in South Asia = ",format(range_south_asia,'.2f'))
# Out:
# The range for score in South Asia =  3.44

# %%
#Computing coefficient of variation for Score in South Asia
cv_south_asia =(std_score_south_asia/mean_score_south_asia)*100
print(f"Coefficient of variation for Score in South Asia = {cv_south_asia:.2f} %")
# Out:
# Coefficient of variation for Score in South Asia = 30.21 %

# %%
#Finding maximum score
max_score_middle_east=MiddleEast['score'].max()

#Finding minimum score
min_score_middle_east=MiddleEast['score'].min()

#Computing range for score in Middle East
range_middle_east=max_score_middle_east-min_score_middle_east
print(f"The range for score in Middle East = ",format(range_middle_east,'.2f'))
# Out:
# The range for score in Middle East =  4.63

# %%
#Computing coefficient of variation for Score in Middle East
cv_middle_east= (std_score_middle_east/mean_score_middle_east)*100
print(f"Coefficient of variation for Score in Middle East = {cv_middle_east:.2f} %")
# Out:
# Coefficient of variation for Score in Middle East = 30.81 %

# %%
#Comparing coefficient of variance of South Asia and Middle East
if cv_south_asia > cv_middle_east:
    print("South Asia has greater variability in happiness.")
else:
    print("Middle East has greater variability in happiness.")
# Out:
# Middle East has greater variability in happiness.

# %% [markdown]
# **5. Correlation Analysis:**
#
# • Analyze the correlation of Score with other metrics Freedom to Make Life Choices, and
# Generosity within each region.
#
# • Create scatter plots to visualize and interpret the relationships.

# %%
#Using the function previously declared in Problem 2 Task 4 Q.no.1 to calculate correlation coefficient
#Calculating correlaton of score with Freedom to Make Life Choices within South Asia
coeff_south_asia1=correlation_coefficient(SouthAsia['Freedom to make life choices'],SouthAsia['score'])

#Calculating correlaton of score with Generosity within South Asia
coeff_south_asia2=correlation_coefficient(SouthAsia['Generosity'],SouthAsia['score'])

print("Pearson correlation coefficient of score with Freedom to Make Life Choices within South Asia = ",format(coeff_south_asia1,'.3f'))
print("Pearson correlation coefficient of score with Generosity within South Asia = ",format(coeff_south_asia2,'.3f'))
# Out:
# Pearson correlation coefficient of score with Freedom to Make Life Choices within South Asia =  0.801
# Pearson correlation coefficient of score with Generosity within South Asia =  0.875

# %%
#Calculating correlaton of score with Freedom to Make Life Choices within Middle East
coeff_middle_east1=correlation_coefficient(MiddleEast['Freedom to make life choices'],MiddleEast['score'])

#Calculating correlaton of score with Generosity within Middle East
coeff_middle_east2=correlation_coefficient(MiddleEast['Generosity'],MiddleEast['score'])

print("Pearson correlation coefficient of score with Freedom to Make Life Choices within Middle East = ",format(coeff_middle_east1,'.3f'))
print("Pearson correlation coefficient of score with Generosity within Middle East = ",format(coeff_middle_east2,'.3f'))
# Out:
# Pearson correlation coefficient of score with Freedom to Make Life Choices within Middle East =  0.863
# Pearson correlation coefficient of score with Generosity within Middle East =  0.628

# %%
#Creating a figure with specified size
plt.figure(figsize=(12,6))

#Plotting scatter plot for Score with Freedom to Make Life Choices within South Asia
plt.subplot(1,2,1)
plt.scatter(SouthAsia['Freedom to make life choices'],SouthAsia['score'],color="skyblue",edgecolor="black")
plt.xlabel("Freedom to Make Life Choices")
plt.ylabel("Score")
plt.title("Score with Freedom to Make Life Choices within South Asia")

#Plotting scatter plot for Score with Freedom to Make Life Choices within Middle East
plt.subplot(1,2,2)
plt.scatter(MiddleEast['Freedom to make life choices'],MiddleEast['score'],color="orange",edgecolor="black")
plt.xlabel("Freedom to Make Life Choices")
plt.ylabel("Score")
plt.title("Score with Freedom to Make Life Choices within Middle East")

plt.tight_layout()
plt.show()

# %% [markdown]
# - > Interpretation:
#
#     The above scatter plot visualizes the distribution of score relative to Freedom to Make Life Choices in both the regions South Asia (left) and Middle East (right). The above scatter plot indicates an upward trend which means that there is a strong positive relationship of Freedom to Make Life Choices with score. Therefore, higher the freedom to make life choices, higher the value of Happiness score.

# %%
#Creating a figure with specified size
plt.figure(figsize=(12,6))

#Plotting scatter plot for Score with Generosity within South Asia
plt.subplot(1,2,1)
plt.scatter(SouthAsia['Generosity'],SouthAsia['score'],color="violet",edgecolor="black")
plt.xlabel("Generosity")
plt.ylabel("Score")
plt.title("Score with Generosity within South Asia")

#Plotting scatter plot for Score with Generosity within Middle East
plt.subplot(1,2,2)
plt.scatter(MiddleEast['Generosity'],MiddleEast['score'],color="brown",edgecolor="black")
plt.xlabel("Generosity")
plt.ylabel("Score")
plt.title("Score with Generosity within Middle East")

plt.tight_layout()
plt.show()

# %% [markdown]
# - > Interpretation:
#
#     The above scatter plot visualizes the distribution of happiness score relative to Generosity of both the regions South Asia (left) and Middle East (right). Here, unlike the scatter plot of Freedom to Make Life Choices with score, the plots are more scattered with no trend. Even more values of scores tend to less values in Generosity. Therefore, there is a weak relationship or correlation between Generosity and Happiness score.

# %% [markdown]
# **6. Outlier Detection:**
#
# • Identify outlier countries in both regions based on Score and GDP per Capita.
#
# • Plot these outliers and discuss their implications.

# %%
#For outliers based on GDP per capita and Score in South Asia, using the code previously done in Task 3 of Problem 2
plt.figure(figsize=(10,6))

#Scatter plot for normal points(non outliers)
non_outliers= (
    (gdp_column >= outlier_gdp_lower) & (gdp_column <= outlier_gdp_upper) &
    (score_column >= outlier_score_lower) & (score_column <= outlier_score_upper)
)
plt.scatter(
    gdp_column[non_outliers],
    score_column[non_outliers],
    color='black', label='Non-outliers'
)

#Scatter plot for Lower outliers
lower_outliers= (
    (gdp_column < outlier_gdp_lower) | (score_column < outlier_score_lower)
)
plt.scatter(
    gdp_column[lower_outliers],
    score_column[lower_outliers],
    color='red', label='Lower Outliers'
)

#Scatter plot for Upper outliers
upper_outliers = (
    (gdp_column > outlier_gdp_upper) | (score_column > outlier_score_upper)
)
plt.scatter(
    gdp_column[upper_outliers],
    score_column[upper_outliers],
    color='green', label='Upper Outliers'
)

# Adding legend, xlabel, ylabel and title
plt.legend()
plt.xlabel('Log GDP per capita')
plt.ylabel('Score')
plt.title('Scatter Plot of Non-Outliers and Outliers in South Asia')
plt.show()

# %% [markdown]
# - > Interpretation:
#
#     The above scatter plot presents non-outliers, lower outliers and upper outliers present in South Asia. It indicates the distribution of happiness scores relative to Log GDP per capita of South Asia. We can observe that one dot is red in color which denotes that one country is a lower outlier indicating that it exceeds the lower bound. This means that one country has unusually low happiness score. Except for one, all the other dots are black which denote there are no more outliers. So, they lie within the lower and upper bound.

# %%
#For score column of Middle East,
#Finding quartile 1 (Q1)
Q1_score=MiddleEast['score'].quantile(0.25)

#Finding quartile 3 (Q3)
Q3_score= MiddleEast['score'].quantile(0.75)

#Finding interquartile range
IQR_score=Q3_score-Q1_score

#Finding the lower and upper outliers
outlier_score_lower=Q1_score-1.5*IQR_score
outlier_score_upper=Q3_score+1.5*IQR_score

#Finding the rows that meet the outliers' condition
score_outliers_middle_east=MiddleEast[(MiddleEast['score']<outlier_score_lower) | (MiddleEast['score']>outlier_score_upper)]
print("Outliers in score column = \n")
score_outliers_middle_east.head()
# Out:
# Outliers in score column =
# Empty DataFrame
# Columns: [Country name, score, Log GDP per capita, Social support, Healthy life expectancy, Freedom to make life choices, Generosity, Perceptions of corruption, Dystopia + residual, Happiness_Category]
# Index: []

# %%
#For Log GDP per capita column of Middle East,
#Finding quartile 1 (Q1)
Q1_gdp=MiddleEast['Log GDP per capita'].quantile(0.25)

#Finding quartile 3 (Q3)
Q3_gdp=MiddleEast['Log GDP per capita'].quantile(0.75)

#Finding interquartile range
IQR_gdp=Q3_gdp-Q1_gdp

#Finding the lower and upper outliers
outlier_gdp_lower=Q1_gdp-1.5*IQR_gdp
outlier_gdp_upper=Q3_gdp+1.5*IQR_gdp

#Finding the rows that meet the outliers' condition
gdp_outliers_middle_east=MiddleEast[(MiddleEast['Log GDP per capita']<outlier_gdp_lower) | (MiddleEast['Log GDP per capita']>outlier_gdp_upper)]
print("Outliers in Log GDP per capita column = \n")
gdp_outliers_middle_east.head()
# Out:
# Outliers in Log GDP per capita column =
# Empty DataFrame
# Columns: [Country name, score, Log GDP per capita, Social support, Healthy life expectancy, Freedom to make life choices, Generosity, Perceptions of corruption, Dystopia + residual, Happiness_Category]
# Index: []

# %%
gdp_column_middle=MiddleEast['Log GDP per capita']
score_column_middle=MiddleEast['score']

# %%
#For outliers based on GDP per capita and Score in South Asia, using the code previously done in Task 3 of Problem 2
plt.figure(figsize=(10,6))

#Scatter plot for normal points(non outliers)
non_outliers= (
    (gdp_column_middle >= outlier_gdp_lower) & (gdp_column_middle <= outlier_gdp_upper) &
    (score_column_middle >= outlier_score_lower) & (score_column_middle <= outlier_score_upper)
)
plt.scatter(
    gdp_column_middle[non_outliers],
    score_column_middle[non_outliers],
    color='black', label='Non-outliers'
)

#Scatter plot for Lower outliers
lower_outliers= (
    (gdp_column_middle < outlier_gdp_lower) | (score_column_middle < outlier_score_lower)
)
plt.scatter(
    gdp_column_middle[lower_outliers],
    score_column_middle[lower_outliers],
    color='red', label='Lower Outliers'
)

#Scatter plot for Upper outliers
upper_outliers = (
    (gdp_column_middle > outlier_gdp_upper) | (score_column_middle > outlier_score_upper)
)
plt.scatter(
    gdp_column_middle[upper_outliers],
    score_column_middle[upper_outliers],
    color='green', label='Upper Outliers'
)

# Adding legend, xlabel, ylabel and title
plt.legend()
plt.xlabel('Log GDP per capita')
plt.ylabel('Score')
plt.title('Scatter Plot of Non-Outliers and Outliers in Middle East')
plt.show()

# %% [markdown]
# - > Interpretation:
#
#     The above scatter plot presents non-outliers, lower outliers and upper outliers present in Middle East. It indicates the distribution of happiness scores relative to Log GDP per capita of Middle East. We can observe that none of the dots are red or green in color which means that all the values for happiness score relative to Log GDP per capita remain inside the lower-upper bound. Therefore, no outliers are present in the data for Middle East.

# %% [markdown]
# **7. Visualization:**
#
# • Create boxplots comparing the distribution of Score between South Asia and the Middle East.
#
# • Interpret the key differences in distribution shapes, medians, and outliers.

# %%
#Creating boxplot comparing the distribution of Score between South Asia and the Middle East.
plt.figure(figsize=(10,6))
plt.boxplot([SouthAsia['score'],MiddleEast['score']],labels=["South Asia","Middle East"],patch_artist=True,boxprops=dict(facecolor='skyblue', color='blue'))
plt.xlabel("Region")
plt.ylabel("Score")
plt.title("Distribution of Score between South Asia and Middle East")
plt.show()

# %% [markdown]
# - > Interpretation:
#
#     Shape: The length of the box plot denotes the interquartile range (IQR) which means that the IQR of Middle East region is more and it has greater spread in scores than that of the South Asia. The whiskers outside the box denote the range of data that are not outliers and lie within the lower and upper bound. South Asia has comparatively shorter whiskers compared to that of Middle East region so South Asia has less variability than Middle East region.
#
#     Median: From the above boxplot, we can observe that the middle line present inside the box of Middle East is higher. This shows that Middle East region has a higher average score compared to South Asia region.
#
#     Outliers: Outliers are the dots which are outside whiskers. We can observe that South Asia has one outlier below the lower whisker which denotes the presence of lower outlier but Middle east region has none. This indicates that South asia region has a country with unusually low score and there is absence of outlier in Middle East region.
